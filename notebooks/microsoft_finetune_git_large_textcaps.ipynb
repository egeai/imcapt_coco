# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn.functional as F
from PIL import Image

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

plt.ion()   # interactive mode

pd.set_option('max_colwidth', 1200)

# %%
torch.__version__
# Out:
# '1.11.0'

# %%
# !pip install -q kaggle
# !pip install transformers
# !pip install wandb -qU
# !pip install -U torchtext
# Out:
# Collecting transformers
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.3 MB 393.8 kB/s eta 0:00:16
#       --------------------------------------- 0.1/6.3 MB 819.2 kB/s eta 0:00:08
#      - -------------------------------------- 0.2/6.3 MB 952.6 kB/s eta 0:00:07
#      - -------------------------------------- 0.3/6.3 MB 1.2 MB/s eta 0:00:05
#      -- ------------------------------------- 0.5/6.3 MB 1.7 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.7/6.3 MB 2.1 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.7/6.3 MB 2.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.7/6.3 MB 1.8 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.7/6.3 MB 1.8 MB/s eta 0:00:04
#      --------- ------------------------------ 1.6/6.3 MB 3.1 MB/s eta 0:00:02
#      ----------- ---------------------------- 1.8/6.3 MB 3.3 MB/s eta 0:00:02
#      ------------ --------------------------- 1.9/6.3 MB 3.3 MB/s eta 0:00:02
#      ------------ --------------------------- 1.9/6.3 MB 3.3 MB/s eta 0:00:02
#      -------------- ------------------------- 2.3/6.3 MB 3.4 MB/s eta 0:00:02
#      ---------------- ----------------------- 2.7/6.3 MB 3.6 MB/s eta 0:00:02
#      ------------------ --------------------- 2.9/6.3 MB 3.7 MB/s eta 0:00:01
#      ------------------- -------------------- 3.1/6.3 MB 3.8 MB/s eta 0:00:01
#      --------------------- ------------------ 3.4/6.3 MB 3.8 MB/s eta 0:00:01
#      ---------------------- ----------------- 3.6/6.3 MB 3.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 3.6/6.3 MB 3.9 MB/s eta 0:00:01
#      ------------------------- -------------- 4.0/6.3 MB 3.9 MB/s eta 0:00:01
#      -------------------------- ------------- 4.1/6.3 MB 3.9 MB/s eta 0:00:01
#      --------------------------- ------------ 4.3/6.3 MB 3.9 MB/s eta 0:00:01
#      ---------------------------- ----------- 4.5/6.3 MB 3.9 MB/s eta 0:00:01
#      ----------------------------- ---------- 4.7/6.3 MB 3.9 MB/s eta 0:00:01
#      ------------------------------- -------- 5.0/6.3 MB 4.0 MB/s eta 0:00:01
#      -------------------------------- ------- 5.2/6.3 MB 4.0 MB/s eta 0:00:01
#      --------------------------------- ------ 5.3/6.3 MB 4.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 5.6/6.3 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------ --- 5.8/6.3 MB 4.0 MB/s eta 0:00:01
#      ------------------------------------- -- 6.0/6.3 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  6.2/6.3 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------  6.3/6.3 MB 4.0 MB/s eta 0:00:01
#      ---------------------------------------- 6.3/6.3 MB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from transformers) (1.24.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from transformers) (6.0)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.10.31-cp310-cp310-win_amd64.whl (267 kB)
#      ---------------------------------------- 0.0/267.7 kB ? eta -:--:--
#      ------------------------------- ------ 225.3/267.7 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 267.7/267.7 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from transformers) (2.28.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from transformers) (23.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.12.1-py3-none-any.whl (190 kB)
#      ---------------------------------------- 0.0/190.3 kB ? eta -:--:--
#      ---------------------------------- --- 174.1/190.3 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------- 190.3/190.3 kB 3.8 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#      -- ------------------------------------- 0.2/3.3 MB 3.9 MB/s eta 0:00:01
#      ---- ----------------------------------- 0.4/3.3 MB 3.8 MB/s eta 0:00:01
#      ------- -------------------------------- 0.6/3.3 MB 4.1 MB/s eta 0:00:01
#      --------- ------------------------------ 0.8/3.3 MB 4.2 MB/s eta 0:00:01
#      ------------ --------------------------- 1.0/3.3 MB 4.3 MB/s eta 0:00:01
#      --------------- ------------------------ 1.2/3.3 MB 4.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 1.5/3.3 MB 4.4 MB/s eta 0:00:01
#      ------------------- -------------------- 1.6/3.3 MB 4.5 MB/s eta 0:00:01
#      ---------------------- ----------------- 1.8/3.3 MB 4.3 MB/s eta 0:00:01
#      ------------------------- -------------- 2.1/3.3 MB 4.4 MB/s eta 0:00:01
#      --------------------------- ------------ 2.3/3.3 MB 4.3 MB/s eta 0:00:01
#      ------------------------------ --------- 2.5/3.3 MB 4.4 MB/s eta 0:00:01
#      -------------------------------- ------- 2.7/3.3 MB 4.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 2.9/3.3 MB 4.4 MB/s eta 0:00:01
#      ------------------------------------- -- 3.1/3.3 MB 4.4 MB/s eta 0:00:01
#      ---------------------------------------  3.3/3.3 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------  3.3/3.3 MB 4.5 MB/s eta 0:00:01
#      ---------------------------------------- 3.3/3.3 MB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda4\envs\torch-cuda-new\lib\site-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, regex, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.12.1 regex-2022.10.31 tokenizers-0.13.2 transformers-4.26.1

# %%
#!rm -rf ~/.kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json "C:\\Users\\User\.kaggle\"
# !chmod 600 "C:\\Users\\User\.kaggle\\kaggle.json"
# !kaggle datasets download -d virajbagal/roco-dataset
# !unzip roco-dataset.zip
# Out:
# Downloading roco-dataset.zip to D:\DeepLearningProjects\MyGithub\img-captioning\notebooks
#   0%|          | 0.00/6.19G [00:00<?, ?B/s]
#   0%|          | 1.00M/6.19G [00:00<37:14, 2.98MB/s]
#   0%|          | 2.00M/6.19G [00:00<31:27, 3.52MB/s]
#   0%|          | 3.00M/6.19G [00:00<29:50, 3.71MB/s]
#   0%|          | 4.00M/6.19G [00:01<27:28, 4.03MB/s]
#   0%|          | 5.00M/6.19G [00:01<26:18, 4.21MB/s]
#   0%|          | 6.00M/6.19G [00:01<27:08, 4.08MB/s]
#   0%|          | 7.00M/6.19G [00:01<27:31, 4.02MB/s]
#   0%|          | 8.00M/6.19G [00:02<26:36, 4.16MB/s]
#   0%|          | 9.00M/6.19G [00:02<29:45, 3.72MB/s]
#   0%|          | 10.0M/6.19G [00:02<28:47, 3.84MB/s]
#   0%|          | 11.0M/6.19G [00:02<27:47, 3.98MB/s]
#   0%|          | 12.0M/6.19G [00:03<27:06, 4.08MB/s]
#   0%|          | 13.0M/6.19G [00:03<27:01, 4.09MB/s]
#   0%|          | 14.0M/6.19G [00:03<26:28, 4.18MB/s]
#   0%|          | 15.0M/6.19G [00:03<26:26, 4.18MB/s]
#   0%|          | 16.0M/6.19G [00:04<25:55, 4.27MB/s]
#   0%|          | 17.0M/6.19G [00:04<25:36, 4.32MB/s]
#   0%|          | 18.0M/6.19G [00:04<25:52, 4.27MB/s]
g002.jpg
#   inflating: all_data/train/radiology/images/PMC2933367_ipej100393-01.jpg
#   inflating: all_data/train/radiology/images/PMC2933459_kcj-40-357-g004.jpg
#   inflating: all_data/train/radiology/images/PMC2933459_kcj-40-357-g006.jpg
#   inflating: all_data/train/radiology/images/PMC2933470_kcj-40-421-g001.jpg
#   inflating: all_data/train/radiology/images/PMC2933470_kcj-40-421-g002.jpg
#   inflating: all_data/train/radiology/images/PMC2933470_kcj-40-421-g003.jpg
#   inflating: all_data/train/radiology/images/PMC2933470_kcj-40-421-g004.jpg
#   inflating: all_data/train/radiology/images/PMC2933487_IJA-54-246-g002.jpg
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Create image captioning dataset

# %%
# !pip install -q datasets

# %% [markdown]
# ### Train Dataset

# %%
captions_train = pd.read_csv("all_data/train/radiologytraindata.csv")
# captions_train = pd.read_csv("all_data/train/radiology/captions.txt", on_bad_lines='skip', sep="\t", names=["id", "caption"])

# %%
captions_train.head()
# Out:
#            id                                    name  \
# 0  ROCO_00002          PMC4083729_AMHSR-4-14-g002.jpg
# 1  ROCO_00003       PMC2837471_IJD2009-150251.001.jpg
# 2  ROCO_00004  PMC2505281_11999_2007_30_Fig6_HTML.jpg
# 3  ROCO_00005       PMC3745845_IJD2013-683423.005.jpg
# 4  ROCO_00007   PMC4917066_amjcaserep-17-301-g001.jpg
#
#                                                                                                                                                                                                                                                                                                                               caption
# 0                                                                                                                                                                                                                                           Computed tomography scan in axial view showing obliteration of the left maxillary sinus\n
# 1                                                                                                                                                                                     Bacterial contamination occurred after completion of root canal treatment in the tooth, which remained with a temporary filling for 15 month.\n
# 2   The patient had residual paralysis of the hand after poliomyelitis. It was necessary to stabilize the thumb with reference to the index finger. This was accomplished by placing a graft from the bone bank between the first and second metacarpals. The roentgenogram shows the complete healing of the graft one year later.\n
# 3                                                                                                                                                                                                                                                                                     Panoramic radiograph after immediate loading.\n
# 4                                                                                                                                                                                                       Plain abdomen x-ray: Multiple air levels at the mid-abdomen (arrows), no radiopaque shadow, and no air under the diaphragm.\n

# %%
keywords_train = pd.read_csv("all_data/train/radiology/keywords.txt", on_bad_lines='skip', sep="\t\t", names=["id", "keywords"])
keywords_train.head()
# Out:
#            id  \
# 0  ROCO_00002
# 1  ROCO_00003
# 2  ROCO_00004
# 3  ROCO_00005
# 4  ROCO_00007
#
#                                                                                                                                                                             keywords
# 0                                                                                                                 scan\tmaxillary\tsinu\taxial\ttomography\tobliteration\tview\tleft
# 1                                                                                     canal\tcompletion\ttemporary\tmonth\tfilling\ttreatment\tcontamination\tbacterial\ttooth\troot
# 2  poliomyeliti\tindex\thealing\tnecessary\tcomplete\treference\tresidual\troentgenogram\thand\tmetacarpal\tsecond\tparalysi\tfinger\tyear\tthumb\tpatient\tgraft\tbank\tbone\tfirst
# 3                                                                                                                                          panoramic\tloading\timmediate\tradiograph
# 4                                                                                                    multiple\tradiopaque\tlevel\tdiaphragm\tplain\tair\tabdoman\tshadow\tmidabdoman

# %%
df = pd.merge(captions_train, keywords_train, on="id")
len(df)
# Out:
# 65450

# %%
chest_x_ray_captions_train = df[df.caption.str.contains("chest x-ray", case=False, na=False)]
chest_x_ray_captions_train = chest_x_ray_captions_train.drop("id", axis=1)

chest_x_ray_captions_train.rename(columns = {'name':'file_name', 'caption':'text', 'keywords': 'vocab'}, inplace = True)
len(chest_x_ray_captions_train)
# Out:
# 1735

# %%
# chest_x_ray_captions_train.to_csv('all_data/train/metadata.csv', index=False, encoding='utf-8')

# %%
metadata_df = chest_x_ray_captions_train.copy()
captions = []
for index, row in chest_x_ray_captions_train.iterrows():
  captions.append({"file_name": row["file_name"], "text": row["text"], "vocab": row["vocab"].replace("\t", " ")})

# %%
captions[0]
# Out:
# {'file_name': 'PMC5144533_IJCCM-20-677-g002.jpg',
#  'text': ' Chest X-ray, which confirmed the position of guidewire, extending from the right internal jugular vein up to inferior vena cava\n',
#  'vocab': 'right guidewire jugular xray chest internal vena position'}

# %%
#captions["vocab"]
vocabs = []
for caption in captions:
  vocabs.append(caption['vocab'])

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

tokenizer = get_tokenizer('basic_english')

examples = [
    "The quick mention is: what da, what!",
    "Hey! what are you doning men?"
]

def yield_tokens():
  for vocab in vocabs:
    tokens = tokenizer(vocab)
    yield tokens

# %%
token_generator = yield_tokens()
vocab = build_vocab_from_iterator(token_generator)

# %%
vocab.get_stoi()
# Out:
# {'yellow': 1917,
#  'xraylateral': 1914,
#  'xraydense': 1913,
#  'xraychest': 1912,
#  'worsening': 1909,
#  'wireiabp': 1906,
#  'wg': 1904,
#  'wellcircumscribed': 1903,
#  'water': 1901,
#  'ward': 1900,
#  'voltage': 1898,
#  'vocal': 1897,
#  'visualisation': 1896,
#  'viscu': 1895,
#  'viscera': 1894,
#  'victim': 1891,
#  'venovenou': 1888,
#  'venoveno': 1887,
#  'venoarterial': 1886,
#  'vasculture': 1882,
#  'vascularization': 1880,
#  'v': 1876,
#  'ushaped': 1874,
#  'urgent': 1872,
#  'uneventful': 1868,
#  'undersurface': 1867,
#  'undergone': 1866,
#  'unclear': 1865,
#  'umbilical': 1863,
#  'ul': 1862,
#  'uip': 1861,
#  'twothird': 1858,
#  'twenty': 1856,
#  'tuberculotic': 1852,
#  'trocar': 1850,
#  'tripleluman': 1849,
#  'tricuspid': 1848,
#  'tree': 1846,
#  'transthoracic': 1845,
#  'transplant': 1843,
#  'transparency': 1842,
#  'transfer': 1841,
#  'tram': 1839,
#  'tracheotomy': 1836,
#  'trabeculation': 1834,
#  'tothe': 1832,
#  'top': 1831,
#  'titre': 1828,
#  'tiedown': 1827,
#  'thyroid': 1826,
#  'thrombotic': 1824,
#  'thrombolysi': 1823,
#  'thread': 1818,
#  'thoraxlarge': 1816,
#  'thickwalled': 1811,
#  'thecervical': 1805,
#  'th4th5': 1804,
#  'tetralogy': 1803,
#  'test': 1802,
#  'termination': 1801,
#  'tenting': 1798,
#  'tdh': 1795,
#  'table': 1794,
#  't8': 1793,
#  't6atrial': 1792,
#  't10': 1790,
#  't1': 1789,
#  'systemic': 1788,
#  'system': 1787,
#  'symmetric': 1786,
#  'sweat': 1784,
#  'swallow': 1782,
#  'suture': 1781,
#  'surfactant': 1780,
#  'surface': 1779,
#  'threshold': 1820,
#  'sure': 1778,
#  'supplementation': 1777,
#  'subsequent': 1773,
#  'subacute': 1771,
#  'straight': 1769,
#  'stomachbowel': 1768,
#  'sternotomy': 1767,
#  'steel': 1766,
#  'spite': 1760,
#  'sphincter': 1758,
#  'spherical': 1757,
#  'source': 1755,
#  'softtissuedensity': 1753,
#  'slt': 1750,
#  'skin': 1746,
#  'sulcu': 1776,
#  'sinus': 1743,
#  'sillouette': 1742,
#  'showingnumerou': 1739,
#  'uterine': 1875,
#  'shortening': 1737,
#  'shield': 1736,
#  'setting': 1732,
#  'septic': 1729,
#  'septation': 1728,
#  'subtotal': 1774,
#  'semilunar': 1727,
#  'scrub': 1723,
#  'schwannoma': 1720,
#  'scene': 1719,
#  'scattered': 1718,
#  'scanty': 1717,
#  'scanning': 1716,
#  'sandstorm': 1714,
#  'samepatient': 1712,
#  'rupture': 1711,
#  'rpa': 1709,
#  'routine': 1707,
#  'roscreturn': 1705,
#  'rosc': 1704,
#  'root': 1703,
#  'roentgenogram': 1702,
#  'rightside': 1701,
#  'review': 1697,
#  'retroperitoneal': 1695,
#  'retained': 1691,
#  'resynchronization': 1690,
#  'restoration': 1688,
#  'respirator': 1686,
#  'respect': 1685,
#  'resection': 1684,
#  'repulsion': 1683,
#  'representative': 1682,
#  'representation': 1681,
#  'replacement': 1680,
#  'worker': 1908,
#  'remnant': 1679,
#  'remarkable': 1678,
#  'veinsuperior': 1884,
#  'release': 1677,
#  'reimplant': 1676,
#  'reconstruction': 1672,
#  'readmission': 1668,
#  'radiotherapy': 1663,
#  'radiopacity': 1662,
#  'transatrial': 1840,
#  'radiolucent': 1661,
#  'radiolucency': 1660,
#  'radiologically': 1658,
#  'radio': 1656,
#  'quadrant': 1654,
#  'punctate': 1651,
#  'pseudoaneurysm': 1646,
#  'recipient': 1670,
#  'protrusion': 1644,
#  'proteinosi': 1643,
#  'process': 1642,
#  'proband': 1641,
#  'presented': 1637,
#  'prerepair': 1636,
#  'pregnancy': 1633,
#  'posttreatment': 1625,
#  'postthoracostomy': 1623,
#  'postthoracoplasty': 1622,
#  'postpneumonectomy': 1619,
#  'postpleurodesi': 1618,
#  'theoretical': 1808,
#  'postolt': 1617,
#  'prednisone': 1631,
#  'postintubation': 1615,
#  'postinsertion': 1614,
#  'posterioanterior': 1613,
#  'postdialysi': 1611,
#  'postaspiration': 1610,
#  'postanterior': 1609,
#  'xraybilateral': 1911,
#  'postadmission': 1608,
#  'tularemia': 1854,
#  'porcine': 1605,
#  'sandlike': 1713,
#  'pneumoperitonuem': 1600,
#  'pneumonitic': 1599,
#  'pneumomediastium': 1597,
#  'tenth': 1797,
#  'pluffy': 1594,
#  'pleurisy': 1591,
#  'pleurabased': 1589,
#  'please': 1588,
#  'plant': 1586,
#  'pinchoff': 1585,
#  'physician': 1581,
#  'physical': 1580,
#  'pfo': 1579,
#  'persistence': 1577,
#  'perigastric': 1576,
#  'pericolic': 1575,
#  'pelvi': 1570,
#  'pectorali': 1564,
#  'pda': 1562,
#  'pig': 1583,
#  'patent': 1560,
#  'passage': 1557,
#  'paralysi': 1554,
#  'parallel': 1553,
#  'para': 1550,
#  'paperclip': 1549,
#  'palt': 1546,
#  'pah': 1544,
#  'paddle': 1543,
#  'overload': 1541,
#  'overinflation': 1540,
#  'overexpansion': 1539,
#  'ovarian': 1538,
#  'ovale': 1537,
#  'orotracheal': 1530,
#  'pad': 1542,
#  'original': 1529,
#  'origin': 1528,
#  'themediastinal': 1806,
#  'orifice': 1527,
#  'opacified': 1524,
#  'one': 1521,
#  'normalized': 1512,
#  'operative': 1526,
#  'nonproductive': 1509,
#  'nonhodgkin': 1507,
#  'nn': 1501,
#  'nigerian': 1499,
#  'nhf': 1498,
#  'next': 1497,
#  'necrosi': 1494,
#  'necklace': 1493,
#  'nasointestinal': 1491,
#  'myeloma': 1488,
#  'mycetoma': 1485,
#  'xraynonhomogenou': 1915,
#  'multilobar': 1482,
#  'multilevel': 1481,
#  'mother': 1479,
#  'rt': 1710,
#  'morphologic': 1478,
#  'morgagni': 1477,
#  'morbidly': 1476,
#  'model': 1473,
#  'mmode': 1470,
#  'mitral': 1468,
#  'mitraclip': 1467,
#  'misplaced': 1466,
#  'ofa': 1516,
#  'midlung': 1464,
#  'micronodulation': 1461,
#  'metric': 1458,
#  'mesodextrocardia': 1455,
#  'medication': 1450,
#  'median': 1448,
#  'measuring': 1447,
#  'measure': 1446,
#  'mattres': 1445,
#  'mastiti': 1444,
#  'manubriosternal': 1442,
#  'malpositioning': 1439,
#  'mai': 1436,
#  'malfunction': 1437,
#  'lvr': 1434,
#  'recipienttwin': 1671,
#  'lt': 1429,
#  'lordotic': 1427,
#  'looping': 1426,
#  'premature': 1634,
#  'longaxi': 1425,
#  'loculated': 1423,
#  'local': 1422,
#  'lobulated': 1421,
#  'lobar': 1420,
#  'thoracostomy': 1815,
#  'limit': 1419,
#  'ligation': 1418,
#  'lie': 1417,
#  'levofloxacin': 1416,
#  'lesionsabbreviation': 1415,
#  'leak': 1412,
#  'lavagesurfactant': 1410,
#  'largest': 1405,
#  'technology': 1796,
#  'largesized': 1404,
#  'laparoscopic': 1403,
#  'lady': 1402,
#  'laden': 1401,
#  'knot': 1399,
#  'kerleyb': 1396,
#  'kaposi': 1394,
#  'jejunum': 1393,
#  'iv': 1391,
#  'patahy': 1559,
#  'investigation': 1389,
#  'introduction': 1385,
#  'intraoperative': 1384,
#  'intracardiac': 1382,
#  'slender': 1748,
#  'intrabronchial': 1381,
#  'intraaortic': 1380,
#  'interventricular': 1379,
#  'interatrial': 1373,
#  'intensity': 1372,
#  'prednisolone': 1630,
#  'insufficient': 1371,
#  'insufficiency': 1370,
#  'inspiratory': 1368,
#  'insitu': 1366,
#  'innominate': 1364,
#  'ingurgitation': 1362,
#  'track': 1838,
#  'inguinal': 1361,
#  'ingestion': 1360,
#  'infiltratefibrotic': 1356,
#  'inferomedial': 1354,
#  'induction': 1352,
#  'incomplete': 1349,
#  'pulsegenerator': 1650,
#  'illustration': 1343,
#  'iii': 1342,
#  'idiopathic': 1340,
#  'path': 1561,
#  'icuthe': 1339,
#  'ict': 1338,
#  'icdb': 1337,
#  'icc': 1336,
#  'viru': 1893,
#  'rp': 1708,
#  'ibdrelated': 1335,
#  'hypoplasiaatresia': 1331,
#  'hypoinflation': 1330,
#  'hypertrophic': 1329,
#  'outlet': 1535,
#  'hypertension': 1328,
#  'reactive': 1667,
#  'hyperstimulation': 1327,
#  'hydroaeric': 1325,
#  'night': 1500,
#  'humeri': 1323,
#  'host': 1321,
#  'proxy': 1645,
#  'hospitalisation': 1320,
#  'hollow': 1316,
#  'incidence': 1347,
#  'hodgkin': 1315,
#  'unchanged': 1864,
#  'hiler': 1314,
#  'higher': 1313,
#  'highdensity': 1312,
#  'hiatu': 1311,
#  'hiatal': 1310,
#  'hepatocellular': 1309,
#  'leftward': 1413,
#  'hemosiderin': 1308,
#  'piercing': 1582,
#  'hemidiaphragmatic': 1306,
#  'hemi': 1305,
#  'hellerhoff': 1304,
#  'microcalcification': 1460,
#  'health': 1301,
#  'healing': 1300,
#  'halo': 1298,
#  'tongue': 1829,
#  'haemorrhage': 1297,
#  'haemithorax': 1295,
#  'guidance': 1294,
#  'groove': 1292,
#  'malposition': 1438,
#  'grey': 1291,
#  'greater': 1290,
#  'great': 1289,
#  'granular': 1287,
#  'glucocorticoid': 1286,
#  'gentle': 1284,
#  'gauze': 1283,
#  'gastrothorax': 1282,
#  'ganzlike': 1280,
#  'radiodense': 1657,
#  'possibility': 1607,
#  'gallbladder': 1279,
#  'thinning': 1812,
#  'fundal': 1276,
#  'fundic': 1277,
#  'functional': 1275,
#  'por': 1604,
#  'front': 1274,
#  'from29': 1273,
#  'fresh': 1272,
#  'freeintraperitoneal': 1271,
#  'fragmented': 1270,
#  'fractional': 1269,
#  'foraman': 1268,
#  'following': 1266,
#  'foci': 1264,
#  'floor': 1262,
#  'smudgy': 1752,
#  'flattened': 1261,
#  'fio2': 1258,
#  'fine': 1257,
#  'fifteenyearold': 1256,
#  'fifteenth': 1255,
#  'fibrostreak': 1253,
#  'manifesting': 1441,
#  'fibrocavitatory': 1252,
#  'fibrocalcified': 1251,
#  'fibrocalcific': 1250,
#  'fan': 1248,
#  'factor': 1246,
#  'thromboendarterectomy': 1822,
#  'fact': 1245,
#  'triangular': 1847,
#  'faceon': 1244,
#  'eyelid': 1243,
#  'exvacuo': 1242,
#  'skull': 1747,
#  'shoulder': 1738,
#  'predominant': 1632,
#  'extrapleural': 1241,
#  'ofconsolidation': 1517,
#  'extracardiac': 1240,
#  'extra': 1239,
#  'extent': 1238,
#  'extension': 1237,
#  'exposure': 1234,
#  'explain': 1233,
#  'expiratory': 1232,
#  'expansion': 1231,
#  'existence': 1229,
#  'exertional': 1228,
#  'prepectoral': 1635,
#  'exchange': 1227,
#  'excavatum': 1226,
#  'pectu': 1566,
#  'exacerbation': 1225,
#  'et': 1223,
#  'pleuralbased': 1590,
#  'erroneou': 1222,
#  'episode': 1220,
#  'union': 1869,
#  'epigastric': 1219,
#  'embolotherapy': 1212,
#  'embolized': 1211,
#  'embolism': 1210,
#  'embolised': 1209,
#  'macrophage': 1435,
#  'electrocatheter': 1207,
#  'eighth': 1206,
#  'effective': 1205,
#  'endstage': 1215,
#  'echocardiography': 1201,
#  'ecl': 1202,
#  'eccentricity': 1200,
#  'earlier': 1198,
#  'dynamic': 1196,
#  'tracheoesophageal': 1835,
#  'myelomatou': 1489,
#  'ed': 1203,
#  'dualluman': 1194,
#  'dry': 1193,
#  'drooping': 1192,
#  'drawn': 1191,
#  'osteolytic': 1532,
#  'dramatic': 1190,
#  'doppler': 1187,
#  'dnase': 1186,
#  'dlt': 1185,
#  'distended': 1180,
#  'distant': 1179,
#  'dislodgement': 1177,
#  'dislocated': 1176,
#  'loculation': 1424,
#  'discontinuation': 1175,
#  'dischargecomplete': 1174,
#  'dimension': 1170,
#  'dilation': 1169,
#  'diaphysi': 1168,
#  'dextroposition': 1165,
#  'thoracoscopy': 1814,
#  'deterioration': 1162,
#  'detail': 1161,
#  'deposition': 1157,
#  'demonstrated': 1155,
#  'noninvasive': 1508,
#  'degeneration': 1154,
#  'pseudocystic': 1647,
#  'defined': 1152,
#  'defibrillatorthe': 1151,
#  'day1': 1147,
#  'daughter': 1146,
#  'date': 1145,
#  'dancer': 1144,
#  'cytoplasmic': 1142,
#  'cxrpa': 1140,
#  'cutoff': 1139,
#  'inhomogenou': 1363,
#  'cutaneou': 1138,
#  'curve': 1136,
#  'current': 1135,
#  'cryptococcosi': 1132,
#  'crtd': 1131,
#  'installation': 1369,
#  'crack': 1129,
#  'costal': 1124,
#  'follow': 1265,
#  'corticosteroid': 1123,
#  'correlation': 1121,
#  'copd': 1120,
#  'convexshaped': 1119,
#  'conversion': 1117,
#  'contour': 1116,
#  'constrictive': 1114,
#  'conservative': 1113,
#  'congested': 1111,
#  'confirmation': 1109,
#  'regular': 1675,
#  'infiltrateand': 1355,
#  'hyperlucent': 536,
#  'septum': 1730,
#  'silhouette': 79,
#  'intestinal': 539,
#  'full': 533,
#  'show': 49,
#  'failure': 529,
#  'flow': 1263,
#  'erosion': 526,
#  'vene': 1885,
#  'poor': 1603,
#  'dislocation': 521,
#  'band': 1017,
#  'convex': 516,
#  'ofpulmonary': 1520,
#  'hypoplastic': 1332,
#  'flap': 1260,
#  'circle': 1089,
#  'common': 513,
#  'httpsemremscomtaglvad': 1322,
#  'contusion': 422,
#  'minimal': 236,
#  'atrialcaval': 1005,
#  'breath': 507,
#  'abnormality': 318,
#  'bent': 502,
#  'marking': 177,
#  'puntiform': 1652,
#  'advanced': 491,
#  'renal': 473,
#  'calcification': 168,
#  'party': 1556,
#  'cell': 511,
#  'scapula': 875,
#  'tiny': 481,
#  'mycoplasma': 1487,
#  'characteristic': 668,
#  'leiuru': 1414,
#  'septal': 884,
#  'chylothorax': 669,
#  'trunk': 610,
#  'regression': 471,
#  'red': 194,
#  'mode': 1472,
#  'puncture': 469,
#  'disease': 105,
#  'pressure': 467,
#  'parahilar': 395,
#  'pacing': 457,
#  'compensatory': 514,
#  'groundglas': 328,
#  'antroposterior': 990,
#  'pre': 1628,
#  'postnatal': 465,
#  'stripe': 480,
#  'relation': 584,
#  'hemifield': 1307,
#  'partial': 458,
#  'medial': 450,
#  'bibasal': 1033,
#  'widespread': 487,
#  'character': 1085,
#  'illdefined': 442,
#  'power': 1627,
#  'electrode': 523,
#  'silhoute': 1741,
#  'associated': 497,
#  'blunting': 253,
#  'start': 1765,
#  'pericardiac': 1572,
#  'generator': 436,
#  'soft': 138,
#  'coalescing': 1097,
#  'destruction': 519,
#  'cystic': 424,
#  'compatible': 421,
#  'care': 255,
#  'bony': 417,
#  'acces': 412,
#  'hernial': 743,
#  'abdoman': 411,
#  'type': 406,
#  'progression': 399,
#  'prone': 857,
#  'total': 405,
#  'retrosternal': 474,
#  'tuberculosi': 205,
#  'recurrence': 582,
#  'nail': 392,
#  'trachea': 139,
#  'versu': 929,
#  'metastatic': 390,
#  'anteromedial': 979,
#  'mole': 1474,
#  'membrane': 389,
#  'kidney': 1397,
#  'cerclage': 1082,
#  'ct': 423,
#  'ball': 499,
#  'radiologist': 1659,
#  'bruising': 1051,
#  'mechanical': 388,
#  'extravasation': 528,
#  'luman': 387,
#  'sixth': 891,
#  'hemorrhage': 535,
#  'obese': 816,
#  'posteranterior': 850,
#  'biopsy': 503,
#  'wide': 410,
#  'pericardiotomy': 1573,
#  'mottling': 554,
#  'pretreatment': 1639,
#  'negative': 808,
#  'temporary': 909,
#  'involucrum': 1390,
#  'guide': 378,
#  'fluffy': 376,
#  'pedicle': 1568,
#  'neoplastic': 1495,
#  'extracorporeal': 373,
#  'imatinib': 1344,
#  'examination': 372,
#  'pectoralmuscle': 1565,
#  'fibrotic': 261,
#  'chest': 0,
#  'count': 691,
#  'dyspnea': 371,
#  'larynx': 1406,
#  'definition': 1153,
#  'pigtail': 459,
#  'diameter': 369,
#  'massive': 113,
#  'thoracolumbar': 913,
#  'tubercular': 1851,
#  'intraluminal': 1383,
#  'cavitation': 362,
#  'dilatation': 293,
#  'belly': 1028,
#  'doubleluman': 1189,
#  'carina': 361,
#  'vv': 1899,
#  'themediastinum': 1807,
#  'crescent': 692,
#  'bifid': 356,
#  'pump': 860,
#  'midzone': 335,
#  'mycobacterium': 1486,
#  'arrival': 355,
#  'callu': 1064,
#  'absces': 619,
#  'parasternal': 1555,
#  'fixation': 1259,
#  'aeration': 351,
#  'pttm': 1648,
#  'cycle': 1141,
#  'upright': 348,
#  'repair': 400,
#  'steroid': 345,
#  'reduction': 343,
#  'luminogram': 1430,
#  'diuresi': 1184,
#  'reveal': 220,
#  'infiltrative': 385,
#  'normalization': 1511,
#  'av': 1011,
#  'point': 463,
#  'herniation': 382,
#  'lingual': 786,
#  'transvenou': 919,
#  'periphery': 340,
#  'guidewire': 379,
#  'complication': 679,
#  'bronchoalveolar': 1048,
#  'intubation': 333,
#  'icd': 331,
#  'volume': 158,
#  'abdullahbayrami': 938,
#  'paratracheal': 338,
#  'radioopacity': 862,
#  'graft': 437,
#  'device': 323,
#  'coronary': 322,
#  'multilple': 1484,
#  'auricular': 1009,
#  'openheart': 1525,
#  'fragment': 377,
#  'concave': 680,
#  'sarcoma': 874,
#  'contrast': 321,
#  'pao2': 1548,
#  'border': 89,
#  'woman': 316,
#  'distinct': 1182,
#  'abdominal': 317,
#  'postoperative': 20,
#  'obliteration': 455,
#  'location': 448,
#  'asymptomatic': 640,
#  'round': 311,
#  'coil': 320,
#  'radioopaque': 310,
#  'preserved': 1638,
#  'clue': 1096,
#  'presence': 308,
#  'perpendicular': 841,
#  'metallic': 304,
#  'cuff': 1134,
#  'man': 303,
#  'metastasi': 451,
#  'acute': 120,
#  'smoke': 1751,
#  'early': 1199,
#  'aortic': 159,
#  'apice': 636,
#  'pleura': 460,
#  'clearance': 365,
#  'increased': 300,
#  'relative': 472,
#  'bochdalek': 649,
#  'girl': 297,
#  'percutaneou': 1571,
#  'apparent': 286,
#  'computed': 1107,
#  'glenohumeral': 732,
#  'reperfusion': 866,
#  'control': 290,
#  'plate': 1587,
#  'second': 129,
#  'support': 606,
#  'linear': 302,
#  'baseline': 501,
#  'haemopneumothorax': 1296,
#  'stage': 896,
#  'costodiaphragmatic': 1126,
#  'state': 897,
#  'implementation': 1345,
#  'age': 283,
#  'sharp': 887,
#  'active': 282,
#  'bronchu': 141,
#  'human': 747,
#  'range': 1664,
#  'oneyear': 1522,
#  'absence': 281,
#  'symptom': 280,
#  'comparison': 677,
#  'vasculatureand': 1881,
#  'mesalazine': 801,
#  'subclavian': 279,
#  'discharge': 121,
#  'structure': 277,
#  'site': 598,
#  'ventilator': 1889,
#  'nonalbendazole': 1505,
#  'portion': 307,
#  'showing': 276,
#  'hydrothorax': 1326,
#  'cta': 1133,
#  'post': 397,
#  'present': 274,
#  'humeru': 440,
#  'vessel': 485,
#  'centralized': 1080,
#  'placement': 273,
#  'old': 271,
#  'new': 269,
#  'icu': 384,
#  'miliary': 268,
#  'lavage': 446,
#  'meningocele': 1452,
#  'secondary': 401,
#  'primary': 398,
#  'attempt': 1007,
#  'mass': 266,
#  'circulation': 1090,
#  'male': 265,
#  'cut': 1137,
#  'last': 782,
#  'mesocardia': 1454,
#  'persistent': 306,
#  'intensive': 264,
#  'vap': 1878,
#  'previou': 239,
#  'inseparable': 1365,
#  'narrowing': 556,
#  'postmitral': 1616,
#  'herniated': 744,
#  'elevated': 259,
#  'lvadcourtesy': 1433,
#  'main': 126,
#  'pyothorax': 1653,
#  'final': 531,
#  'nodule': 58,
#  'catscratch': 1076,
#  'hospital': 174,
#  'decreased': 367,
#  'infection': 444,
#  'white': 56,
#  'emboli': 1208,
#  'aneurysm': 352,
#  'lat': 1407,
#  'pneumothorace': 341,
#  'surgery': 131,
#  'left': 4,
#  'suffering': 904,
#  'ventricular': 119,
#  'orogastric': 820,
#  'tumor': 250,
#  'markingsabbreviation': 1443,
#  'removal': 344,
#  'anc': 413,
#  'cd4': 666,
#  'luminal': 789,
#  'extreme': 718,
#  'pa': 24,
#  'breast': 418,
#  'small': 107,
#  'extensive': 106,
#  'xray': 1,
#  'acquired': 940,
#  'appropriate': 994,
#  'posterioranterior': 104,
#  'healthy': 741,
#  'segment': 402,
#  'arteriovenou': 496,
#  'dual': 429,
#  'supine': 314,
#  'midline': 267,
#  'mild': 91,
#  'diagnosi': 292,
#  'patchy': 103,
#  'middle': 57,
#  'retrospective': 1696,
#  'inspiration': 1367,
#  'cxr': 163,
#  'monitoring': 1475,
#  'nasogastric': 237,
#  'military': 1465,
#  'merge': 1453,
#  'portable': 95,
#  'medical': 1449,
#  'tension': 347,
#  'rarification': 1666,
#  'hilar': 90,
#  'field': 18,
#  'region': 97,
#  'intubated': 1386,
#  'level': 77,
#  'roundedoval': 1706,
#  'adjacent': 350,
#  'erect': 260,
#  'azygo': 642,
#  'subxiphoid': 1775,
#  'spleen': 1761,
#  'amplatzer': 963,
#  'mediastinal': 27,
#  'proper': 468,
#  'shifting': 476,
#  'basithoracic': 1023,
#  'pneumomediastinum': 85,
#  'past': 1558,
#  'department': 256,
#  'unit': 251,
#  'center': 1079,
#  'ofmeconium': 1519,
#  'd2d3': 1143,
#  'spine': 403,
#  'kyphoscoliosi': 545,
#  'lead': 84,
#  'change': 111,
#  'printing': 1640,
#  '4th': 934,
#  'airbronchogram': 492,
#  'score': 879,
#  'airspace': 109,
#  'rightleft': 1700,
#  'subdiaphragmatic': 346,
#  'cavitary': 153,
#  'superior': 80,
#  'thoracic': 98,
#  'jugular': 117,
#  'cannulae': 1065,
#  'se': 1725,
#  'radiopaque': 470,
#  'heterogeneou': 263,
#  'artery': 66,
#  'course': 229,
#  'position': 48,
#  'pleurodesi': 1592,
#  'multilobulated': 1483,
#  'costochondral': 1125,
#  'fistula': 375,
#  'pulmonary': 7,
#  'thorax': 182,
#  'pouch': 1626,
#  'carcinoma': 660,
#  'diabetes': 1166,
#  'immediate': 443,
#  'tip': 92,
#  'lv': 549,
#  'american': 629,
#  'thorocostomy': 1817,
#  'homogenou': 146,
#  'thymu': 1825,
#  'development': 700,
#  'case': 61,
#  'edema': 63,
#  'sarcoidosi': 873,
#  'femoral': 721,
#  'intraperitoneal': 540,
#  'pin': 1584,
#  'abduction': 937,
#  'aorta': 353,
#  'cervicothoracic': 1084,
#  'outline': 394,
#  'body': 115,
#  'endomyocardial': 1213,
#  'pericardial': 166,
#  'density': 62,
#  'plethora': 843,
#  'spontaneou': 313,
#  'bigger': 1034,
#  'bone': 254,
#  'described': 1158,
#  'narrow': 454,
#  'cavity': 110,
#  'diffuse': 31,
#  'dexamethasone': 1163,
#  'subphrenic': 604,
#  'wire': 227,
#  'tomography': 608,
#  'internal': 100,
#  'oedematou': 1515,
#  'size': 204,
#  'management': 1440,
#  'rib': 50,
#  'bilateral': 5,
#  'pleuropneumonia': 1593,
#  'bullet': 359,
#  'scoliosi': 244,
#  'thick': 911,
#  'deformity': 426,
#  'operation': 272,
#  'asthmaticu': 1001,
#  'history': 746,
#  'unnormal': 1870,
#  'vertebral': 408,
#  'institution': 768,
#  'effusion': 10,
#  'presentation': 60,
#  'cardiogenic': 1069,
#  'frontal': 532,
#  'area': 69,
#  'consistent': 170,
#  'month': 54,
#  'fibrou': 1254,
#  'hazines': 232,
#  'complete': 86,
#  'pneumopericardium': 461,
#  'pneumatic': 1595,
#  'upper': 13,
#  'metaphyse': 1456,
#  'free': 124,
#  'amiodarone': 962,
#  'posttransplant': 1624,
#  'year': 150,
#  'reticularnodular': 1692,
#  'cervical': 363,
#  'thin': 404,
#  'image': 76,
#  'fiber': 1249,
#  'eosinophilic': 1217,
#  'space': 245,
#  'osteonecrosi': 1534,
#  'luscency': 1432,
#  'opacification': 102,
#  'focal': 434,
#  'radiological': 242,
#  'hernia': 262,
#  'vascularity': 407,
#  'service': 1731,
#  'black': 82,
#  'homogeneou': 234,
#  'brachiocephalic': 506,
#  'chamber': 364,
#  'radiography': 309,
#  ...}

# %%
import json

# path to the folder containing the images
root = "/content/all_data/train/"

# add metadata.jsonl file to this folder
with open(root + "metadata.jsonl", 'w') as f:
    for item in captions:
        f.write(json.dumps(item) + "\n")

# %%
# Copy train images under the train folder

import shutil

for index, row in chest_x_ray_captions_train.iterrows():
  colab_link = "/content/all_data/train/radiology/images/" + row['file_name']
  gdrive_link = "/content/all_data/train"
  shutil.copy(colab_link, gdrive_link)

# %% [markdown]
# ### Test Dataset

# %%
captions_test = pd.read_csv("all_data/test/radiologytestdata.csv")
keywords_test = pd.read_csv("all_data/test/radiology/keywords.txt", on_bad_lines='skip', sep="\t\t", names=["id", "keywords"])
df_test = pd.merge(captions_test, keywords_test, on="id")
df_test.head()

# %%
chest_x_ray_captions_test = df_test[df_test.caption.str.contains("chest x-ray", case=False, na=False)]
chest_x_ray_captions_test = chest_x_ray_captions_test.drop("id", axis=1)

chest_x_ray_captions_test.rename(columns = {'name':'file_name', 'caption':'text', 'keywords': 'vocab'}, inplace = True)
len(chest_x_ray_captions_test)
# Out:
# 199

# %%
metadata_test_df = chest_x_ray_captions_test.copy()
captions_test = []
for index, row in metadata_test_df.iterrows():
  captions_test.append({"file_name": row["file_name"], "text": row["text"], "vocab": row["vocab"].replace("\t", " ")})

# %%
#captions["vocab"]
vocabs = []
for caption in captions_test:
  vocabs.append(caption['vocab'])

# %%
import json

# path to the folder containing the images
root = "/content/all_data/test/"

# add metadata.jsonl file to this folder
with open(root + "metadata.jsonl", 'w') as f:
    for item in captions_test:
        f.write(json.dumps(item) + "\n")

# %%
# Copy test images under the test folder

import shutil

for index, row in chest_x_ray_captions_test.iterrows():
  colab_link = "/content/all_data/test/radiology/images/" + row['file_name']
  gdrive_link = "/content/all_data/test"
  shutil.copy(colab_link, gdrive_link)

# %% [markdown]
# ### Validation Dataset

# %%
captions_val = pd.read_csv("all_data/validation/radiologyvaldata.csv")
keywords_val = pd.read_csv("all_data/validation/radiology/keywords.txt", on_bad_lines='skip', sep="\t\t", names=["id", "keywords"])
df_val = pd.merge(captions_val, keywords_val, on="id")
df_val.head()
# Out:
#            id                                    name  \
# 0  ROCO_00020    PMC3970251_CRIONM2014-931546.003.jpg
# 1  ROCO_00027          PMC2766744_cios-1-176-g005.jpg
# 2  ROCO_00059  PMC3789931_poljradiol-78-3-35-g001.jpg
# 3  ROCO_00062               PMC2676075_p147_fig4a.jpg
# 4  ROCO_00068    PMC5292123_CRIGM2017-1710501.002.jpg
#
#                                                                                                                                                           caption  \
# 0                                    Axial computed tomography scan of the pelvis showing a diffuse infiltration of the bladder wall, catheter in situ (arrow).\n
# 1                                                                                                       Postoperative anteroposterior radiograph of the pelvis.\n
# 2   Angiography of the internal carotid artery, late arterial phase. (A) – venous drainage of the AVM, (B) – main arterial supplying vessel, arrow – AVM nidus.\n
# 3                                  Case 4: (A) pretreatment radiograph; (B) Root-canal filled showing one canal with a lot of foraminas around the apical area.\n
# 4                                                                Preintervention MRCP revealing a nine-millimeter stone in the cystic duct (marked with arrow).\n
#
#                                                                                                          keywords
# 0                     pelvi\tscan\twall\tbladder\tsitu\taxial\tarrow\tinfiltration\ttomography\tcatheter\tdiffuse
# 1                                                               postoperative\tpelvi\tradiograph\tanteroposterior
# 2  arterial\tangiography\tnidu\tvenou\tdrainage\tlate\tavm\tinternal\tarrow\tcarotid\tphase\tartery\tmain\tvessel
# 3                                   canal\tcase\tapical\trootcanal\tforamina\tpretreatment\tarea\tradiograph\tlot
# 4                                               mrcp\tstone\tninemillimeter\tpreintervention\tduct\tarrow\tcystic

# %%
chest_x_ray_captions_val = df_val[df_val.caption.str.contains("chest x-ray", case=False, na=False)]
chest_x_ray_captions_val = chest_x_ray_captions_val.drop("id", axis=1)

chest_x_ray_captions_val.rename(columns = {'name':'file_name', 'caption':'text', 'keywords': 'vocab'}, inplace = True)
len(chest_x_ray_captions_val)
# Out:
# 222

# %%
metadata_val_df = chest_x_ray_captions_val.copy()
captions_val = []
for index, row in metadata_val_df.iterrows():
  captions_val.append({"file_name": row["file_name"], "text": row["text"], "vocab": row["vocab"].replace("\t", " ")})

# %%
import json

# path to the folder containing the images
root = "/content/all_data/validation/"

# add metadata.jsonl file to this folder
with open(root + "metadata.jsonl", 'w') as f:
    for item in captions_val:
        f.write(json.dumps(item) + "\n")

# %%
# Copy validation images under the validation folder

import shutil

for index, row in chest_x_ray_captions_val.iterrows():
  colab_link = "/content/all_data/validation/radiology/images/" + row['file_name']
  gdrive_link = "/content/all_data/validation"
  shutil.copy(colab_link, gdrive_link)

# %%
# !rm -rf "/content/all_data/train/non-radiology/"
# !rm -rf "/content/all_data/train/radiology/"

# !rm -rf "/content/all_data/test/non-radiology/"
# !rm -rf "/content/all_data/test/radiology/"

# !rm -rf "/content/all_data/validation/non-radiology/"
# !rm -rf "/content/all_data/validation/radiology/"

# %%
from datasets import load_dataset 
root = "all_data/"
train_dataset = load_dataset("imagefolder", data_dir=root, split="train")
val_dataset = load_dataset("imagefolder", data_dir=root, split="validation")
test_dataset = load_dataset("imagefolder", data_dir=root, split="test")
# Out:
# Resolving data files:   0%|          | 0/1737 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/201 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/224 [00:00<?, ?it/s]
# WARNING:datasets.builder:Using custom data configuration default-51644c2e44f22ec5
# Downloading and preparing dataset imagefolder/default to /root/.cache/huggingface/datasets/imagefolder/default-51644c2e44f22ec5/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f...
# Downloading data files:   0%|          | 0/1739 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/203 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/226 [00:00<?, ?it/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset imagefolder downloaded and prepared to /root/.cache/huggingface/datasets/imagefolder/default-51644c2e44f22ec5/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f. Subsequent calls will reuse this data.
# Resolving data files:   0%|          | 0/1737 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/201 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/224 [00:00<?, ?it/s]
# WARNING:datasets.builder:Using custom data configuration default-51644c2e44f22ec5
# WARNING:datasets.builder:Found cached dataset imagefolder (/root/.cache/huggingface/datasets/imagefolder/default-51644c2e44f22ec5/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)
# Resolving data files:   0%|          | 0/1737 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/201 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/224 [00:00<?, ?it/s]
# WARNING:datasets.builder:Using custom data configuration default-51644c2e44f22ec5
# WARNING:datasets.builder:Found cached dataset imagefolder (/root/.cache/huggingface/datasets/imagefolder/default-51644c2e44f22ec5/0.0.0/37fbb85cc714a338bea574ac6c7d0b5be5aff46c1862c1989b20e0771199e93f)

# %%
train_dataset
# Out:
# Dataset({
#     features: ['image', 'text'],
#     num_rows: 1735
# })

# %%
example = train_dataset[0]
image = example["image"]
print(example['vocab'])
width, height = image.size
display(image.resize((int(0.3*width), int(0.3*height))))
# Out:
# bilateral admission xray chest lung infiltration girl film
# <PIL.Image.Image image mode=L size=180x138 at 0x7F5DAD62AB50>

# %% [markdown]
# ## Create PyTorch Dataset

# %%
from torch.utils.data import Dataset

class ImageCaptioningDataset(Dataset):
    def __init__(self, dataset, processor, annotations_file, vocab):
        self.dataset = dataset
        self.processor = processor
        self.vocab = vocab
        self.transform = transforms.Compose([ 
            transforms.Resize(224),
            transforms.RandomCrop(224),
            transforms.RandomHorizontalFlip(), 
            transforms.ToTensor(), 
            transforms.Normalize((0.485, 0.456, 0.406), 
                                 (0.229, 0.224, 0.225))]
        )

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]

        caption = item.caption
        tokens = str(caption).lower().split()
        target = []
        target.append(vocab.stoi['<start>'])
        target.extend([vocab.stoi[token] for token in tokens])
        target.append(vocab.stoi['<end>'])
        target = torch.Tensor(target).long()


        encoding = self.processor(images=item["image"], text=item["text"], label=label, padding="max_length", return_tensors="pt")
        # remove batch dimension
        encoding = {k:v.squeeze() for k,v in encoding.items()}

        return encoding

# %% [markdown]
# ## Load model and processor

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
loss = torch.nn.BCELoss(size_average=True)

criterion = torch.nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else torch.nn.CrossEntropyLoss()

# %%
import requests
# from PIL import Image
from transformers import AutoModelForCausalLM, AutoProcessor

processor = AutoProcessor.from_pretrained("microsoft/git-base-coco")
model = AutoModelForCausalLM.from_pretrained("microsoft/git-base-coco").to("cuda")
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/503 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   0%|          | 0.00/707M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]

# %%
processor
# Out:
# GitProcessor:
# - image_processor: CLIPImageProcessor {
#   "crop_size": {
#     "height": 224,
#     "width": 224
#   },
#   "do_center_crop": true,
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "CLIPImageProcessor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "processor_class": "GitProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "shortest_edge": 224
#   }
# }
#
# - tokenizer: BertTokenizerFast(name_or_path='microsoft/git-base-coco', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
train_dataset = ImageCaptioningDataset(train_dataset, processor)
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=2)

val_dataset = ImageCaptioningDataset(val_dataset, processor)
val_dataloader = DataLoader(val_dataset, batch_size=2)

# %%
batch = next(iter(train_dataloader))
for k,v in batch.items():
  print(k,v.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-559e64c2c8a5> in <module>
# ----> 1 batch = next(iter(train_dataloader))
#       2 for k,v in batch.items():
#       3   print(k,v.shape)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# <ipython-input-43-1e4b4aec72ac> in __getitem__(self, idx)
#      14         if self.labels:
#      15           item["labels"] = torch.tensor(self.labels[idx])
# ---> 16         encoding = self.processor(images=item["image"], text=item["text"], padding="max_length", return_tensors="pt")
#      17         # remove batch dimension
#      18         encoding = {k:v.squeeze() for k,v in encoding.items()}
#
# KeyError: 'image'

# %% [markdown]
# ## Dummy forward pass

# %%
def train(model, device, train_dataloader, optimizer, epoch):
  train_loss=[]
  train_accuracy=[]
  test_accuracy=[]

  progress_bar = tqdm(range(num_training_steps))

  model.train()
  for idx, batch in enumerate(train_dataloader):
    input_ids = batch.pop("input_ids").to(device)
    attention_mask = batch.pop("attention_mask").to(device)
    pixel_values = batch.pop("pixel_values").to(device)

    outputs = model(input_ids=input_ids,
                    pixel_values=pixel_values,
                    labels=input_ids)
    
    print(outputs.loss, outputs.logits.shape)
  
    loss = outputs.loss
    loss.backward()
    train_loss.append(loss.item())

    optimizer.step()
    lr_scheduler.step()
    optimizer.zero_grad()
    progress_bar.update(1)

# %%
from datasets import load_metric

def evaluate(model, device, eval_dataloader):
  metric = load_metric("glue", "mrpc")
  model.eval()
  #for batch in eval_dataloader:
  for idx, batch in enumerate(eval_dataloader):
    input_ids = batch.pop("input_ids").to(device)
    attention_mask = batch.pop("attention_mask").to(device)
    pixel_values = batch.pop("pixel_values").to(device)

    print("dir(batch)")
    print(dir(batch))

    """
    batch = {k: v.to(device) for k, v in batch.items()}
    print(batch)
    """
    with torch.no_grad():
      outputs = model(input_ids=input_ids,
                pixel_values=pixel_values,
                labels=input_ids)
      #outputs = model(**batch)

    logits = outputs.logits
    predictions = torch.argmax(logits, dim=-1).flatten()

    print("pixel_values.shape")
    print(pixel_values.shape)

    print("input_ids.shape")
    print(input_ids.shape)

    print("predictions.shape")
    print(predictions.shape)

    metric.add_batch(predictions=predictions, references=input_ids)
  metric.compute()

# %%
from torch.optim import lr_scheduler
from transformers import get_scheduler
from tqdm.auto import tqdm
num_epochs = 3
num_training_steps = num_epochs * len(train_dataloader)

optimizer = torch.optim.AdamW(model.parameters(), lr=5e-5)

lr_scheduler = get_scheduler(
    name="linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=num_training_steps
)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)



for epoch in range(num_epochs):
  train(model, device, train_dataloader, optimizer, epoch)
  #evaluate(model, device, val_dataloader)

# %% [markdown]
# ## Inference

# %%
# load image
example = train_dataset[0]
image = example["image"]
width, height = image.size
display(image.resize((int(0.3*width), int(0.3*height))))

# %%
# prepare image for the model
inputs = processor(images=image, return_tensors="pt").to(device)
pixel_values = inputs.pixel_values

generated_ids = model.generate(pixel_values=pixel_values, max_length=50)
generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(generated_caption)

# %% [markdown]
# ## Fine-tuning in PyTorch with the Trainer API

# %%
import numpy as np
from datasets import load_metric

metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    logits, input_ids = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=input_ids)

# %%
from transformers import TrainingArguments
from transformers import Trainer

training_args = TrainingArguments(
    "test_trainer",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    learning_rate=2e-5,
    weight_decay=0.01
)

trainer = Trainer(
    model=model, 
    args=training_args, 
    train_dataset=train_dataset, 
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 1735
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 545
#   Number of trainable parameters = 176619066
# vision_config is None. initializing the GitVisionConfig with default values.
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-58889527a2eb> in <module>
#      19 )
#      20
# ---> 21 trainer.train()
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1541             self._inner_training_loop, self._train_batch_size, args.auto_find_batch_size
#    1542         )
# -> 1543         return inner_training_loop(
#    1544             args=args,
#    1545             resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1789                         tr_loss_step = self.training_step(model, inputs)
#    1790                 else:
# -> 1791                     tr_loss_step = self.training_step(model, inputs)
#    1792
#    1793                 if (
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in training_step(self, model, inputs)
#    2537
#    2538         with self.compute_loss_context_manager():
# -> 2539             loss = self.compute_loss(model, inputs)
#    2540
#    2541         if self.args.n_gpu > 1:
#
# /usr/local/lib/python3.8/dist-packages/transformers/trainer.py in compute_loss(self, model, inputs, return_outputs)
#    2582         else:
#    2583             if isinstance(outputs, dict) and "loss" not in outputs:
# -> 2584                 raise ValueError(
#    2585                     "The model did not return a loss from the inputs, only the following keys: "
#    2586                     f"{','.join(outputs.keys())}. For reference, the inputs it received are {','.join(inputs.keys())}."
#
# ValueError: The model did not return a loss from the inputs, only the following keys: logits,past_key_values. For reference, the inputs it received are input_ids,attention_mask,pixel_values.

# %%
model_save_name = 'microsoft_git_image_captioning.pt'
path = f"/content/gdrive/MyDrive/NioyatechTask/models/{model_save_name}"
model.save_pretrained(path) 
  #torch.save(model.state_dict(), path)
  #load_state_dict(torch.load(path))

# %%
"""
model.train()
total_loss = 0

for epoch in range(num_epochs):
  print("Epoch:", epoch)
  for idx, batch in enumerate(train_dataloader):
    input_ids = batch.pop("input_ids").to(device)
    pixel_values = batch.pop("pixel_values").to(device)

    outputs = model(input_ids=input_ids,
                    pixel_values=pixel_values,
                    labels=input_ids)
    
    loss = outputs.loss
    # total_loss += loss

    print("Loss:", loss.item())
    # print("Total Loss:", total_loss)

    loss.backward()

    optimizer.step()
    optimizer.zero_grad()
    if idx:
        wandb.log({"loss": loss})

# torch.save(model.state_dict(), "/content/all_data/models")
"""

# %%
#training_args = TrainingArguments("test-trainer")

# %%
"""
trainer = Trainer(
    model,
    training_args,
    train_dataset=dataset,
    eval_dataset=dataset_validation
)
"""

# %%
"""
def evaluate(model, device, test_dataloader):
  loss = 0
  success = 0

  num_correct = 0
  num_samples = 0
  total_loss = 0

  losstensorMean = 0


  # Tracking variables
  val_accuracy = []
  val_loss = []
  f1_weighted = []

  result = []
  model.eval()
  with torch.no_grad():
    for batch in test_dataloader:

      # input_ids, pixel_values = input_ids.to(device), pixel_values.to(device)
      input_ids = batch.pop("input_ids").to(device)
      # batch.pop("input_ids").type(torch.FloatTensor).to(device)
      pixel_values = batch.pop("pixel_values").to(device)

      ""
      captions = model.generate(pixel_values, num_beams=3, 
                                max_length=20, 
                                min_length=5)
        
      for caption, img_id in zip(captions, input_ids):
          result.append({"image_id": img_id.item(), "caption": caption})
      ""

      #outputs = model(input_ids=input_ids,
      #     pixel_values=pixel_values,
      #     labels=input_ids)

      pred_prob = model(input_ids=input_ids, attention_mask=batch["attention_mask"])
      
      #print("pred_prob.logits")
      #print(pred_prob.logits.shape)
      #print("pred_prob[0]")
      #print(pred_prob[0].shape)

      itm_score = torch.nn.functional.softmax(pred_prob.logits, dim=1)[:, 1]
      print("itm_score")
      print(itm_score)

      loss += F.nll_loss(pred_prob[:,1], input_ids, reduction='sum').item() # loss summed across the batch
      print("loss")
      print(loss)

      ""
      # loss = criterion(pred_prob.logits, batch.view(1, -1))
      print("loss")
      print(pred_prob.logits.shape)
      print(pred_prob[0].shape)
      print("input_ids.shape")
      print(input_ids.shape)

      predictions = torch.argmax(pred_prob[0], dim=2)
      print("predictions")
      print(predictions)
      print("predictions.shape")
      print(predictions.shape)
      ""
      #correct_predictions = sum(predictions==input_ids).item()
      #print("correct_predictions")
      #print(correct_predictions)

      #losstensor = loss(pred_prob.logits, input_ids)
      #print("losstensor")
      #print(losstensor)
      
      # logits = outputs[0]

      # print(logits)

      ## val_loss.append(outputs.loss.item())

      # Calculate the accuracy rate
      #accuracy = (predictions == input_ids).cpu().numpy().mean() * 100
      #print(accuracy)
      #val_accuracy.append(accuracy)


      #print(val_accuracy)

      # print(type(pixel_values))

      #losstensor = loss(pred_prob.logits, input_ids)
      #print(losstensor)
      # losstensorMean += losstensor
        
      # lossVal += losstensor.item()
      # lossValNorm += 1

      #total_loss += outputs.loss.item()
    #print("Total loss", total_loss)

    # outLoss = lossVal / lossValNorm
    # losstensorMean = losstensorMean / lossValNorm

    # return outLoss, losstensorMean
      
      #itm_score = torch.nn.functional.softmax(pred_prob, dim=1)[:, 1]
      
      #print(itm_score)

      #_, predictions = pred_prob.max(1)
      #num_correct += (itm_score == input_ids).sum()
      #num_samples += itm_score.size(0)

    #print(f"Got {num_correct} / {num_samples} with accuracy {float(num_correct)/float(num_samples)*100:.2f}")
      
      # loss = pred_prob.loss
      # pred_prob = model(input_ids)

      # loss += F.nll_loss(pred_prob, pixel_values, reduction='sum').item() # loss summed across the batch
      
      # logits_per_image = pred_prob.logits_per_image
      # probs = logits_per_image.softmax(dim=1)
  

      # pred = pred_prob.argmax(dim=1, keepdim=True)  # us argmax to get the most likely prediction
      # success += pred.eq(pixel_values.view_as(pred)).sum().item()
  # loss /= len(test_dataloader.dataset)
  # print('\nTest dataset: Overall Loss: {:.4f}, Overall Accuracy: {}/{} ({:.0f}%)\n'.format(
  #    loss, success, len(test_dataloader.dataset),
  #    100. * success / len(test_dataloader.dataset)))


"""

# %%
    """

    #model.eval()
    with torch.no_grad():
      check_accuracy(val_dataloader, model)
      #for val_image, val_label in val_dataloader:
      #  evaluate(model, val_dataloader)

      #print("pixel_values.shape")
      #print(pixel_values.shape)
      #output_test = model(pixel_values)
      #test_accuracy.append(get_accuracy(outputs, input_ids))

    if (epoch + 1) % 5 == 0:
      print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss.item():.4f}, Train Accuracy: {sum(train_accuracy)/len(train_accuracy):.2f}")
    ""
          print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss.item():.4f}, 
          Train Accuracy: {sum(train_accuracy)/len(train_accuracy):.2f}, 
          Test Accuracy: {sum(test_accuracy)/len(test_accuracy):.2f}")
    if idx % 10 == 0:
      wandb.log({"loss": loss})
      print('epoch: {} [{}/{} ({:.0f}%)]\t training loss: {:.6f}'.format(
          epoch, idx * len(input_ids), 
          len(train_dataloader.dataset),
          100. * idx / len(train_dataloader), 
          loss.item()))
    ""
  return train_loss, train_accuracy
  """
# Out:
# '\n\n#model.eval()\nwith torch.no_grad():\n  check_accuracy(val_dataloader, model)\n  #for val_image, val_label in val_dataloader:\n  #  evaluate(model, val_dataloader)\n\n  #print("pixel_values.shape")\n  #print(pixel_values.shape)\n  #output_test = model(pixel_values)\n  #test_accuracy.append(get_accuracy(outputs, input_ids))\n\nif (epoch + 1) % 5 == 0:\n  print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss.item():.4f}, Train Accuracy: {sum(train_accuracy)/len(train_accuracy):.2f}")\n""\n      print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss.item():.4f}, \n      Train Accuracy: {sum(train_accuracy)/len(train_accuracy):.2f}, \n      Test Accuracy: {sum(test_accuracy)/len(test_accuracy):.2f}")\nif idx % 10 == 0:\n  wandb.log({"loss": loss})\n  print(\'epoch: {} [{}/{} ({:.0f}%)]\t training loss: {:.6f}\'.format(\n      epoch, idx * len(input_ids), \n      len(train_dataloader.dataset),\n      100. * idx / len(train_dataloader), \n      loss.item()))\n""\n  return train_loss, train_accuracy\n  '

# %%
"""
def check_accuracy(loader, model):
    num_correct = 0
    num_samples = 0
    model.eval()
    ""
    print({k: v.shape for k, v in batch.items()})
    {
      'input_ids': torch.Size([2, 512]), 
      'attention_mask': torch.Size([2, 512]), 
      'pixel_values': torch.Size([2, 3, 224, 224])
    }

    print({k: v.shape for k, v in batch2.items()})
    {'input_ids': torch.Size([2, 512]), 
    'attention_mask': torch.Size([2, 512]), 
    'pixel_values': torch.Size([2, 3, 224, 224])
    }
    for idx, batch in enumerate(train_dataloader):


    
    with torch.no_grad():
      for batch in loader: 

        #input_ids = batch.pop("input_ids").to(device)
        #pixel_values = batch.pop("pixel_values").to(device)
        #attention_mask = batch.pop("attention_mask").to(device)

        #scores = model(input_ids=input_ids, 
        #                attention_mask=attention_mask)

        batch = {k: v.to(device) for k, v in batch.items()}
        scores = model(**batch)

        predictions = torch.argmax(scores.logits)

        print("scores.logits.shape")
        print(scores.logits.shape)

        print("predictions")
        print(predictions)

        print("input_ids")
        print(input_ids)

        num_correct += (predictions == input_ids).sum()
        num_samples += predictions.size(0)

        print(f'Got {num_correct} / {num_samples} with accuracy {float(num_correct)/float(num_samples)*100:.2f}') 

      model.train()
  """"
